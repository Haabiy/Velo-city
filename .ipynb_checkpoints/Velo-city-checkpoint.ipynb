# %% [markdown]
# # <font color='Orange'>Velo-city</font>

# %%
import pandas as pd
import csv
from time import sleep
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
# source : url
driver = webdriver.Chrome(ChromeDriverManager().install())
url = 'https://www.velo-city2022.com/Programme/#r5hv0j4'
driver.get(url)
sleep(2)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\adema\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# C:\Users\adema\AppData\Local\Temp\ipykernel_18860\506695225.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %% [markdown]
# ### <font color='Orange'>Opening ceremony</font>

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')}
ttbody = soup.find('div', {'class' : 'card matchthis'})
title = ttbody.find('div', {'class' : 'card-title plenary'})
print(title)
# Out:
# <div class="card-title plenary">OPENING CEREMONY</div>

# %% [markdown]
#    ### <font color='Orange'>Extract the names, professions and locations of the speakers</font>

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %%
# Make sure you click either on profiles or section of topics to see the lists before running the next lines of code
body = soup.find('div', {'id' : 'mainbody'})
row = body.find('div', {'class' : 'row'})

def extract():
    file = open('Velo-city.csv', 'w', encoding='utf-8')
    try:
        for c1 in row.find_all('div', {'class' : 'col-12 col-md-3 mb-3'}):
            name = c1.find_all('h6')[0].text.strip()
            job = c1.find_all('em')[0].text.strip()
            location = c1.find_all('p')[1].text.strip()
            ff = csv.writer(file)
            ff.writerow([name, job, location])
            print(name, job, location)
    except Exception:
        pass

# trims empty cells in between
def trim():
    df = pd.read_csv('Velo-city.csv')
    df.to_csv('Velo-city.csv', index=False)
    readfile = pd.read_csv('Velo-city.csv')
    dataframe = pd.DataFrame(readfile)
    #dataframe.columns = ["Name", "Job position", "Location"]
    return dataframe

# %%
for i in range(1):
    extract()
# Out:
# Mojca Mavec Velo-city Master of Ceremony, TV presenter and travel journalist Slovenia
# Urša Pintar Professional Racing Cyclist, UCI Women's World Team Slovenia
# Zoran Janković Mayor, City of Ljubljana Slovenia
# Henk Swarttouw ECF President, European Cyclists' Federation The Netherlands

# %%
trim()
# Out:
#       Mojca Mavec  \
# 0     Urša Pintar
# 1  Zoran Janković
# 2  Henk Swarttouw
#
#   Velo-city Master of Ceremony, TV presenter and travel journalist  \
# 0  Professional Racing Cyclist, UCI Women's World...
# 1                           Mayor, City of Ljubljana
# 2       ECF President, European Cyclists' Federation
#
#           Slovenia
# 0         Slovenia
# 1         Slovenia
# 2  The Netherlands
